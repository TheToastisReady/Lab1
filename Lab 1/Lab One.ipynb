# %%
import statistics as stat
import matplotlib.pyplot as plt
% matplotlib inline

#File Reading
#Emma Anderson, Big Data, 9/7/16
#open and save the file for reading
data_file = open("FreBridge1.csv", "r");
#create an empty list to store the data
data_list = [];
#put all lines from the file into a list
for ii in data_file:
    data_list.append(ii);

#remove the first element (column header)
del data_list[0];
#create empty lists for westbound and eastbound bikes
west = [];
east = [];    
for jj in range(len(data_list)):
    #make into a list of lists of just numbers
    data_list[jj] = data_list[jj].split(",");
    #add data to specific lists for west and east
    west.append(int(data_list[jj][1]));
    east.append(int(data_list[jj][2]));
meh = 1;
total = [];
for mer in range(len(west)):
    
    bleh = west[mer];
    blah = east[mer];
    ech = bleh + blah;
    total.append(ech);
    print("The total for 9 /",mer+1,"/ 2015 is: ",ech);
    
print(west);
print(east);
print("The mean of the west is: ",stat.mean(west));
print("The median of the west is: ",stat.median(west));
try:
    print("The mode of the west is: ",stat.mode(west));
except:
    print("There is no unique mode for the west.");
print("The mean of the east is: ",stat.mean(east));
print("The median of the east is: ",stat.median(east));
try:
    print("The mode of the east is: ",stat.mode(east));
except:
    print("There is no unique mode for the east.");
# Out:
# The total for 9 / 1 / 2015 is:  2876
# The total for 9 / 2 / 2015 is:  3612
# The total for 9 / 3 / 2015 is:  3159
# The total for 9 / 4 / 2015 is:  2937
# The total for 9 / 5 / 2015 is:  1596
# The total for 9 / 6 / 2015 is:  891
# The total for 9 / 7 / 2015 is:  2005
# The total for 9 / 8 / 2015 is:  3665
# The total for 9 / 9 / 2015 is:  4313
# The total for 9 / 10 / 2015 is:  4030
# The total for 9 / 11 / 2015 is:  3761
# The total for 9 / 12 / 2015 is:  2191
# The total for 9 / 13 / 2015 is:  1327
# The total for 9 / 14 / 2015 is:  3284
# The total for 9 / 15 / 2015 is:  3657
# The total for 9 / 16 / 2015 is:  3731
# The total for 9 / 17 / 2015 is:  2453
# The total for 9 / 18 / 2015 is:  3000
# The total for 9 / 19 / 2015 is:  1834
# The total for 9 / 20 / 2015 is:  1303
# The total for 9 / 21 / 2015 is:  3805
# The total for 9 / 22 / 2015 is:  4551
# The total for 9 / 23 / 2015 is:  4562
# The total for 9 / 24 / 2015 is:  4321
# The total for 9 / 25 / 2015 is:  2684
# ...

# %% [markdown]
# These numbers signify the amount of bicycles that crossed the Fremont bridge in one day on the East and West side in the real world. Out of all the statistical computations that this data was put through, I think mean is the most useful, because the data we are sorting is recorded over time and therefore suggests we are most likely looking for averages. The median is just the middle point, which isn't very useful when you don't know what day it is and takes away a sense of scale for the rest of the data. Another thing I would try to calculate the total traffic for both sides because it would give me reference of scale for total traffic compared day by day. Out of all the days, 9/22/2015 had the most traffic in one day as an individual side while 9/29/2015 had the most in total combination. I know this because I did some math to calculate the amount of traffic combined for both sides per day in Python, which showed 9/22/2015 and 9/29/2015 had the largest values.

# %%
import statistics as stat
import matplotlib.pyplot as plt
% matplotlib inline

#File Reading
#Andrew Gladden, Big Data, 9/7/16
#open and save the file for reading
data_file = open("FreBridge2.csv", "r");
#create an empty list to store the data
data_list = [];
#put all lines from the file into a list
for ii in data_file:
    data_list.append(ii);

#remove the first element (column header)
del data_list[0];
#create empty lists for westbound and eastbound bikes
west = [];
east = [];
date = [];
for jj in range(len(data_list)):
    #make into a list of lists of just numbers
    data_list[jj] = data_list[jj].split(",");
    #add data to specific lists for west and east
    west.append(int(data_list[jj][1]));
    east.append(int(data_list[jj][2]));
    #time for dates
    date.append(data_list[jj][0]);
    
month = [];
year = [];

#Arrays for average and prediction calculation
psep12 = [];
psep13 = [];
psep14 = [];
psep15 = [];
psep16 = [];
ps13 = [];
ps14 = [];
ps15 = [];
tat13 = [];
tat14 = [];
tat15 = [];
tat16 = [];

#Day recording
ms13 = [];
tus13 = [];
ws13 = [];
ths13 = [];
fs13 = [];
sas13 = [];
sus13 = [];
ms14 = [];
tus14 = [];
ws14 = [];
ths14 = [];
fs14 = [];
sas14 = [];
sus14 = [];
ms15 = [];
tus15 = [];
ws15 = [];
ths15 = [];
fs15 = [];
sas15 = [];
sus15 = [];
ma13 = [];
tua13 = [];
wa13 = [];
tha13 = [];
fa13 = [];
saa13 = [];
sua13 = [];
ma14 = [];
tua14 = [];
wa14 = [];
tha14 = [];
fa14 = [];
saa14 = [];
sua14 = [];
ma15 = [];
tua15 = [];
wa15 = [];
tha15 = [];
fa15 = [];
saa15 = [];
sua15 = [];
ma16 = [];
tua16 = [];
wa16 = [];
tha16 = [];
fa16 = [];
saa16 = [];
sua16 = [];

#For loop to append arrays with appropriate values
for kk in range(len(date)):
    #Date splitter
    date[kk] = date[kk].split("/");
    month.append(int(date[kk][0]));
    year.append(int(date[kk][2]));
#C = 'Current'
cmonth = "";
cyear = "";
cday = 0;
total = [];
ocday = "";
chk = 1;
censor = 1;

for mer in range(len(west)):
    
    #Total calculation for complete data set
    bleh = west[mer];
    blah = east[mer];
    blergh = (mer+3)%7
    ech = bleh + blah;
    total.append(int(ech));
    
    #September prediction array data sorting
    if month[mer] == 9 and year[mer] == 13:
        psep13.append(total[mer]);
    elif month[mer] == 9 and year[mer] == 14:
        psep14.append(total[mer]);
    elif month[mer] == 9 and year[mer] == 15:
        psep15.append(total[mer]);
    elif month[mer] == 8 and year[mer] == 16:
        psep16.append(total[mer]);
    elif month[mer] == 8 and year[mer] == 13:
        ps13.append(total[mer]);
    elif month[mer] == 8 and year[mer] == 14:
        ps14.append(total[mer]);
    elif month[mer] == 8 and year[mer] == 15:
        ps15.append(total[mer]);
        
    if blergh == 3:#Wednesday
        cday = 3;
        ocday = "Wed";
    elif blergh == 4:#Thursday
        cday = 4;
        ocday = "Thur";
    elif blergh == 5:#Friday
        cday = 5;
        ocday = "Fri";
    elif blergh == 6:#Saturday
        cday = 6;
        ocday = "Sat";
    elif blergh == 0:#Sunday
        cday = 7;
        ocday = "Sun";
    elif blergh == 1:#Monday
        cday = 1;
        ocday = "Mon";
    elif blergh == 2:#Tuesday
        cday = 2;
        ocday = "Tue";
    
    #[Day] of [Month] of [Year] recording
    if month[mer] == 8:
        if year[mer] == 13:
            if cday == 5:
                fa13.append(total[mer]);
            elif cday == 4:
                tha13.append(total[mer]);
        elif year[mer] == 14:
            if cday == 5:
                fa14.append(total[mer]);
            elif cday == 4:
                tha14.append(total[mer]);
        elif year[mer] == 15:
            if cday == 5:
                fa15.append(total[mer]);
            elif cday == 4:
                tha15.append(total[mer]);
        elif year[mer] == 16:
            if cday == 5:
                fa16.append(total[mer]);
            elif cday == 4:
                tha16.append(total[mer]);
    elif month[mer] == 9:
        if year[mer] == 13:
            if cday == 5:
                fs13.append(total[mer]);
            elif cday == 4:
                ths13.append(total[mer]);
        elif year[mer] == 14:
            if cday == 5:
                fs14.append(total[mer]);
            elif cday == 4:
                ths14.append(total[mer]);
        elif year[mer] == 15:
            if cday == 5:
                fs15.append(total[mer]);
            elif cday == 4:
                ths15.append(total[mer]);
    
    if month[mer] == 8 or month[mer] == 7 or month[mer] == 6 or month[mer] == 5 or month[mer] == 4 or month[mer] == 3 or month[mer] == 2 or month[mer] == 1:
        if year[mer] == 13:
            tat13.append(total[mer]);
        elif year[mer] == 14:
            tat14.append(total[mer]);
        elif year[mer] == 15:
            tat15.append(total[mer]);
        elif year[mer] == 16:
            if month[mer] == 2:
                if censor == 29:
                    print("Gotcha bitch", censor);
                    censor = censor + 1;
                else:
                    tat16.append(total[mer]);
                    censor = censor + 1;
            else:
                tat16.append(total[mer]);



#Thursday to Friday transition calculation of last fri for sept
tfs13 = fs13[3]/ths13[3];
tfs14 = fs14[3]/ths14[3];
tfs15 = fs15[3]/ths15[3];

#Total Thu to Fri transition for sept
ttfs13 = stat.mean(fs13)/stat.mean(ths13);
ttfs14 = stat.mean(fs14)/stat.mean(ths14);
ttfs15 = stat.mean(fs15)/stat.mean(ths15);

#Thursday to Friday transition calculation for aug
ttfa13 = stat.mean(fa13)/stat.mean(tha13);
ttfa14 = stat.mean(fa14)/stat.mean(tha14);
ttfa15 = stat.mean(fa15)/stat.mean(tha15);
ttfa16 = stat.mean(fa16)/stat.mean(tha16);

#Friday averaging (Of August, which is what I wanted in the first place)
afa13 = stat.mean(fa13);
afa14 = stat.mean(fa14);
afa15 = stat.mean(fa15);
afa16 = stat.mean(fa16);

#fsept:taug calc
fsta13 = fs13[3]/afa13;
fsta14 = fs14[3]/afa14;
fsta15 = fs15[3]/afa15;
afsta = (fsta13+fsta14+fsta15)/3;

#Differences and averages calculated below p = predicted a = august/average d = difference
pa3 = stat.mean(psep13);
pa4 = stat.mean(psep14);
pa5 = stat.mean(psep15);
aa6 = stat.mean(psep16);
aa3 = stat.mean(ps13);
aa4 = stat.mean(ps14);
aa5 = stat.mean(ps15);
d1 = pa4-pa3;
d2 = pa5-pa4;
dt = pa5-pa3;

#Aug->Sep transition calc
as3 = pa3-aa3;
as4 = pa4-aa4;
as5 = pa5-aa5;

#Avg trans rate adjustment (for everything ever)
p1 = as4/as3;
p2 = as5/as4;
astr = [p1,p2];
ta = stat.mean(astr);
fa = as5*ta;
fp = aa6+fa;

#Friday averaging (Of September, so you don't lose yer mind ANDY!)
asf = [fs13[3], fs14[3], fs15[3]];
pd3 = asf[0]/pa3;
pd4 = asf[1]/pa4;
pd5 = asf[2]/pa5;
pdaa6 = [pd3, pd4, pd5];#Predicted difference averaging array
pdaf = stat.mean(pdaa6);
pdff = fp*pdaf;

#Total of each year to the end of august for foot traffic
atat13 = sum(tat13);
atat14 = sum(tat14);
atat15 = sum(tat15);
atat16 = sum(tat16);

#Ratio of total traffic up to end of aug under final fri of sep for cor year & rate calc
rtat13 = fs13[3]/atat13;
rtat14 = fs14[3]/atat14;
rtat15 = fs15[3]/atat15;
rctat1 = rtat14-rtat13;
rctat2 = rtat15-rtat14;
avgofthistuff = (rctat1+rctat2)/2;
nowimadditogether = avgofthistuff+rtat15;

#Meth 2 of calc, Find the average final fri of aug compared to the final sept as a ratio
pdff2 = afa16*afsta;

#Meth 3 of calc, Find average fri of aug with adjustment rate compared to final sept as ratio
pdff3 = atat16*nowimadditogether;

#Meth 4 of calc, average all meths
FFFFFFINISH_HIM = (pdff+pdff2+pdff3)/3;


#Prints
print("Transition of average thurs-->fri sept", ttfs13, ttfs14, ttfs15);
print("fsep:taug ratio/13/14/15/avg", fsta13, fsta14, fsta15, afsta);
print("Predicted difference 3/4/5", pd3, pd4, pd5);
print("Friday/Thursday transitional ratio 13/14/15", tfs13, tfs14, tfs15);
print("Total for up to the end of Aug 13/14/15/16", atat13, atat14, atat15, atat16);
print("Ratio for up to the end of Aug 13/14/15/16 under final fri of sep", rtat13, rtat14, rtat15);
print("^dat shit but moar", rctat1, rctat2, avgofthistuff, nowimadditogether);
print("Predicted difference final", pdaf);
print("predic 1", p1);
print("predic 2", p2);
print("avg of predics", ta);
print("Final something, forgot what 'a' stood for",fa);
print("final prediction",fp);
print("2013 sep",pa3);
print("2014 sep",pa4);
print("2015 sep",pa5);
print("2013 aug",aa3);
print("2014 aug",aa4);
print("2015 aug",aa5);
print("2016 aug",aa6);
print("Aug->Sep transition 2013",as3);
print("Aug->Sep transition 2014",as4);
print("Aug->Sep transition 2015",as5);
print("Fridays of all augusts", fa13, fa14, fa15, fa16);
print("Fridays of all septembers", fs13, fs14, fs15);
print("Predicted outcome via meth 1:", pdff);
print("Predicted outcome via meth 2:", pdff2);
print("Predicted outcome via meth 3:", pdff3);
print();
print();
print();
print("The number you've all been waiting for.....", FFFFFFINISH_HIM);
print("Made by");
print("        ,-.      .-,");
print("        |-.\ __ /.-|");
print("        \  `    `  /");
print("        / _     _  \\");
print("        | _`q  p _ |");
print("        '._=/  \=_.'");
print("          {`\()/`}`\\");
print("          {      }  \\");
print("          |{    }    \\");
print("          \ '--'   .- \\");
print("          |-      /    \\");
print("          | | | | |     ;");
print("          | | |.;.,..__ |");
print("        .-\"\";`         `|");
print("       /    |           /");
print("       `-../____,..---'`");
print("Fox~");




#        ,-.      .-,
#        |-.\ __ /.-|
#        \  `    `  /
#        / _     _  \
#        | _`q  p _ |
#        '._=/  \=_.'
#          {`\()/`}`\
#          {      }  \
#          |{    }    \
#          \ '--'   .- \
#          |-      /    \
#          | | | | |     ;
#          | | |.;.,..__ |
#        .-"";`         `|
#       /    |           /
#       `-../____,..---'`
# Out:
# Gotcha bitch 29
# Transition of average thurs-->fri sept 0.7799486594409584 0.9421004206098843 0.8867721836281601
# fsep:taug ratio/13/14/15/avg 0.6300944115404914 0.6895699456253089 0.8643426455196844 0.728002334228495
# Predicted difference 3/4/5 0.7985977777502509 0.7721560507595482 0.8834759710335747
# Friday/Thursday transitional ratio 13/14/15 0.5947965679490728 0.8477380148548278 0.6211525109928258
# Total for up to the end of Aug 13/14/15/16 663375 719957 711753 874846
# Ratio for up to the end of Aug 13/14/15/16 under final fri of sep 0.0032394950065950633 0.003487708293689762 0.003770971109359567
# ^dat shit but moar 0.0002482132870946989 0.000283262815669805 0.0002657380513822519 0.004036709160741819
# Predicted difference final 0.8180765998477912
# predic 1 0.5527970202138918
# predic 2 0.7853551064206262
# avg of predics 0.669076063317259
# Final something, forgot what 'a' stood for -197.98176544545868
# final prediction 3427.179524877122
# 2013 sep 2690.9666666666667
# ...

# %% [markdown]
# Spare code:
#
# if blergh == 3:
#         print("The total for day",mer+1,"is: ",ech,"and it is a wednesday during",cmonth,"of the year",cyear);
#     elif blergh == 4:
#         print("The total for day",mer+1,"is: ",ech,"and it is a thursday during",cmonth,"of the year",cyear);
#     elif blergh == 5:
#         print("The total for day",mer+1,"is: ",ech,"and it is a friday during",cmonth,"of the year",cyear);
#     elif blergh == 6:
#         print("The total for day",mer+1,"is: ",ech,"and it is a saturday during",cmonth,"of the year",cyear);
#     elif blergh == 0:
#         print("The total for day",mer+1,"is: ",ech,"and it is a sunday during",cmonth,"of the year",cyear);
#     elif blergh == 1:
#         print("The total for day",mer+1,"is: ",ech,"and it is a monday during",cmonth,"of the year",cyear);
#     elif blergh == 2:
#         print("The total for day",mer+1,"is: ",ech,"and it is a tuesday during",cmonth,"of the year",cyear);
#     blergh == blergh + 1;
#
#
#
# print(west);
# print(east);
# print("The mean of the west is: ",stat.mean(west));
# print("The median of the west is: ",stat.median(west));
# try:
#     print("The mode of the west is: ",stat.mode(west));
# except:
#     print("There is no unique mode for the west.");
# print("The mean of the east is: ",stat.mean(east));
# print("The median of the east is: ",stat.median(east));
# try:
#     print("The mode of the east is: ",stat.mode(east));
# except:
#     print("There is no unique mode for the east.");
#
# pwest = plt.hist(west);
#
#
#
#
# #Year and month finder, only here if I decide to add the date tracker again
#     if year[mer] == 12:
#         cyear = "2012";
#     elif year[mer] == 13:
#         cyear = "2013";
#     elif year[mer] == 14:
#         cyear = "2014";
#     elif year[mer] == 15:
#         cyear = "2015";
#     elif year[mer] == 16:
#         cyear = "2016";
#     if month[mer] == 1:
#         cmonth = "January";
#     elif month[mer] == 2:
#         cmonth = "February";
#     elif month[mer] == 3:
#         cmonth = "March";
#     elif month[mer] == 4:
#         cmonth = "April";
#     elif month[mer] == 5:
#         cmonth = "May";
#     elif month[mer] == 6:
#         cmonth = "June";
#     elif month[mer] == 7:
#         cmonth = "July";
#     elif month[mer] == 8:
#         cmonth = "August";
#     elif month[mer] == 9:
#         cmonth = "September";
#     elif month[mer] == 10:
#         cmonth = "October";
#     elif month[mer] == 11:
#         cmonth = "November";
#     elif month[mer] == 12:
#         cmonth = "December";

# %%
for ii in 34:
